# %%
import numpy as np
from matplotlib import pyplot as plt

stretchedGrid = False

nx = 100
ny = 100
nz = 100

dx = 1000 # m
dy = 1000 # m
dz = 1 # m

x = np.arange(0, nx*dx, dx)
y = np.arange(0, ny*dy, dy)
z = np.arange(0, nz*dz, dz)

# %%
def centers_to_edges_1d(x):
    # Assuming evenly spaced x values
    dx = x[1]-x[0]
    # Translate all points by a value of dx/2
    x = x-dx/2
    # Append a new point located dx units past the last data point
    return np.insert(x,-1,x[-1]+dx)

y_edge = centers_to_edges_1d(y)
z_edge = centers_to_edges_1d(z)

Y_edge,Z_edge = np.meshgrid(y_edge,z_edge)

print(Y_edge.shape, Z_edge.shape)
# Out:
# (87, 101) (87, 101)

# %%
if stretchedGrid:
    data = np.load('parPlate.npz', allow_pickle=True)
else:
    data =np.load('press_evenGrid.npz')
lst = data.files

print(lst)
# Out:
# ['pb', 'pd', 'pdl', 'pdnl', 'prspert']

# %%
pb = data['pb']

# %%
# plt.plot(pb[50,:,:])

if stretchedGrid:
    stretchedTitle = "Stretched Vertical Grid"
    stretchedName = "stretched.png"
else:
    stretchedTitle = "Uniform Vertical Grid"
    stretchedName = "uniform.png"

fig = plt.figure(figsize=(6,4))
plt.xlabel('Y (km)')
plt.ylabel('Z (m)')
plt.title('Middle of X domain -- ' + stretchedTitle)
plt.pcolormesh(y_edge/1000, z_edge, np.transpose(pb[np.int(nx/2),:,:]))
cb = plt.colorbar(im)
cb.set_label('Potential')

plt.savefig('./cross_' + stretchedName)

fig = plt.figure(figsize=(6,4))
plt.xlabel('Height (m)')
plt.ylabel('Potential')
plt.title('Middle of X-Y domain -- ' + stretchedTitle)
plt.plot(z,pb[np.int(nx/2),np.int(ny/2),:])

plt.savefig('./center_' + stretchedName)
